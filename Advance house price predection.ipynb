# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import matplotlib_inline 
import seaborn as sns 
pd.pandas.set_option("display.max_columns",None)

# %%
dataset=pd.read_csv("train.csv")

# %%
dataset.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %% [markdown]
# # IN dataanalysis we need to find below value
# 1.Missing value
# 2.All the numberical variable
# 3.distribtion of numerical variable
# 4.categorical variable
# 5.cardinality of catorigal variable
# 6.outliers
# 7.relationship between independent and dependent feature(dsales price)

# %%
feature_with_na = [feature for feature in dataset.columns if dataset[feature].isnull().sum() > 1]
for feature in feature_with_na:
                 print(feature,np.round(dataset[feature].isnull().mean(),4),"% missing value")
# Out:
# LotFrontage 0.1774 % missing value
# Alley 0.9377 % missing value
# MasVnrType 0.5973 % missing value
# MasVnrArea 0.0055 % missing value
# BsmtQual 0.0253 % missing value
# BsmtCond 0.0253 % missing value
# BsmtExposure 0.026 % missing value
# BsmtFinType1 0.0253 % missing value
# BsmtFinType2 0.026 % missing value
# FireplaceQu 0.4726 % missing value
# GarageType 0.0555 % missing value
# GarageYrBlt 0.0555 % missing value
# GarageFinish 0.0555 % missing value
# GarageQual 0.0555 % missing value
# GarageCond 0.0555 % missing value
# PoolQC 0.9952 % missing value
# Fence 0.8075 % missing value
# MiscFeature 0.963 % missing value

# %%
for feature in feature_with_na:
    data=dataset.copy()

# %%
data[feature]=np.where(data[feature].isnull(),1,0)
# sns.barplot(data,x=data[feature],y="SalePrice",estimator="median", width=0.06)
data.groupby (feature)['SalePrice'].median().plot.bar()
plt.ylabel("salePrice")
plt.xlabel(feature )
plt.show()

# %%
print("Id of the house{}".format(len(dataset.Id)))
# Out:
# Id of the house1460

# %%
num_feature=[feature for feature in dataset.columns if dataset[feature].dtypes!="O"]
print("numerical feature",len(num_feature))
dataset[num_feature].head()
# Out:
# numerical feature 38
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          2003       196.0         706           0        150          856
# 1          1976         0.0         978           0        284         1262
# 2          2002       162.0         486           0        434          920
# 3          1970         0.0         216           0        540          756
# 4          2000       350.0         655           0        490         1145
#
# ...

# %%
len(feature_with_na and num_feature)
# Out:
# 38

# %%
year_feature=[feature for feature in num_feature if "Yr" in feature or "Year" in feature]

# %%
len(year_feature)
year_feature
# Out:
# ['YearBuilt', 'YearRemodAdd', 'GarageYrBlt', 'YrSold']

# %%
for feature in year_feature:
    print(feature,dataset[feature].unique())
# Out:
# YearBuilt [2003 1976 2001 1915 2000 1993 2004 1973 1931 1939 1965 2005 1962 2006
#  1960 1929 1970 1967 1958 1930 2002 1968 2007 1951 1957 1927 1920 1966
#  1959 1994 1954 1953 1955 1983 1975 1997 1934 1963 1981 1964 1999 1972
#  1921 1945 1982 1998 1956 1948 1910 1995 1991 2009 1950 1961 1977 1985
#  1979 1885 1919 1990 1969 1935 1988 1971 1952 1936 1923 1924 1984 1926
#  1940 1941 1987 1986 2008 1908 1892 1916 1932 1918 1912 1947 1925 1900
#  1980 1989 1992 1949 1880 1928 1978 1922 1996 2010 1946 1913 1937 1942
#  1938 1974 1893 1914 1906 1890 1898 1904 1882 1875 1911 1917 1872 1905]
# YearRemodAdd [2003 1976 2002 1970 2000 1995 2005 1973 1950 1965 2006 1962 2007 1960
#  2001 1967 2004 2008 1997 1959 1990 1955 1983 1980 1966 1963 1987 1964
#  1972 1996 1998 1989 1953 1956 1968 1981 1992 2009 1982 1961 1993 1999
#  1985 1979 1977 1969 1958 1991 1971 1952 1975 2010 1984 1986 1994 1988
#  1954 1957 1951 1978 1974]
# ...

# %%
dataset.groupby('YrSold')["SalePrice"].median().plot()
# Out:
# <Axes: xlabel='YrSold'>

# %%
for feature in year_feature:
    if feature !='YrSold':
        data=dataset.copy()
        data[feature]=data['YrSold']-data[feature]
        
        plt.scatter(data[feature],data['SalePrice'])
        plt.xlabel(feature)
        plt.ylabel('sale price')
        plt.show()

# %% [markdown]
# # descrete variable

# %%
dis_feature=[feature for feature in num_feature if len(dataset[feature].unique())<25 and feature not in year_feature+["ID"]]

print("Descrete variable count:{}".format(len(dis_feature)))
# Out:
# Descrete variable count:17

# %%
dis_feature
# Out:
# ['MSSubClass',
#  'OverallQual',
#  'OverallCond',
#  'LowQualFinSF',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'TotRmsAbvGrd',
#  'Fireplaces',
#  'GarageCars',
#  '3SsnPorch',
#  'PoolArea',
#  'MiscVal',
#  'MoSold']

# %%
dis_feature
# Out:
# ['MSSubClass',
#  'OverallQual',
#  'OverallCond',
#  'LowQualFinSF',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'TotRmsAbvGrd',
#  'Fireplaces',
#  'GarageCars',
#  '3SsnPorch',
#  'PoolArea',
#  'MiscVal',
#  'MoSold']

# %%
dataset[dis_feature].head()
# Out:
#    MSSubClass  OverallQual  OverallCond  LowQualFinSF  BsmtFullBath  \
# 0          60            7            5             0             1
# 1          20            6            8             0             0
# 2          60            7            5             0             1
# 3          70            7            5             0             1
# 4          60            8            5             0             1
#
#    BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr  TotRmsAbvGrd  \
# 0             0         2         1             3             1             8
# 1             1         2         0             3             1             6
# 2             0         2         1             3             1             6
# 3             0         1         0             3             1             7
# 4             0         2         1             4             1             9
#
#    Fireplaces  GarageCars  3SsnPorch  PoolArea  MiscVal  MoSold
# ...

# %%
for feature in dis_feature:
    data=dataset.copy()
    data.groupby(feature)["SalePrice"].median().plot.bar()
    plt.xlabel(feature)
    plt.show()

# %%
cont_feature=[feature for feature in num_feature if feature not in dis_feature+year_feature+["Id"]]
print("countinous feature:{}".format(len(cont_feature))) 
cont_feature
# Out:
# countinous feature:16
# ['LotFrontage',
#  'LotArea',
#  'MasVnrArea',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'GrLivArea',
#  'GarageArea',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  'ScreenPorch',
#  'SalePrice']

# %%
for feature in cont_feature:
    data=dataset.copy()
    data[feature].hist(bins=20)
    plt.xlabel(feature)
    plt.ylabel("count")
    cont_feature
    plt.show()

# %% [markdown]
# # Exploratory data analysis

# %% [markdown]
# # outlaiers

# %%
for feature in cont_feature:
    data=dataset.copy()
    if 0 in data[feature].unique():
        pass
    else:
        data[feature]
        data[feature]=np.log(data[feature])
        data['SalePrice']=np.log(data['SalePrice'])
        plt.scatter(data[feature],data["SalePrice"])
        plt.xlabel(feature)
        plt.ylabel('SalePrice')
        plt.show()

# %%
data=dataset.copy()

# %%
cato_feature= [feature for feature in dataset.columns if data[feature].dtypes=="O"]
len(cato_feature)
# Out:
# 43

# %%
for feature in cato_feature:
    print("the feature of {} and catogry is{}".format(feature,data[feature].unique()))
# Out:
# the feature of MSZoning and catogry is['RL' 'RM' 'C (all)' 'FV' 'RH']
# the feature of Street and catogry is['Pave' 'Grvl']
# the feature of Alley and catogry is[nan 'Grvl' 'Pave']
# the feature of LotShape and catogry is['Reg' 'IR1' 'IR2' 'IR3']
# the feature of LandContour and catogry is['Lvl' 'Bnk' 'Low' 'HLS']
# the feature of Utilities and catogry is['AllPub' 'NoSeWa']
# the feature of LotConfig and catogry is['Inside' 'FR2' 'Corner' 'CulDSac' 'FR3']
# the feature of LandSlope and catogry is['Gtl' 'Mod' 'Sev']
# the feature of Neighborhood and catogry is['CollgCr' 'Veenker' 'Crawfor' 'NoRidge' 'Mitchel' 'Somerst' 'NWAmes'
#  'OldTown' 'BrkSide' 'Sawyer' 'NridgHt' 'NAmes' 'SawyerW' 'IDOTRR'
#  'MeadowV' 'Edwards' 'Timber' 'Gilbert' 'StoneBr' 'ClearCr' 'NPkVill'
#  'Blmngtn' 'BrDale' 'SWISU' 'Blueste']
# the feature of Condition1 and catogry is['Norm' 'Feedr' 'PosN' 'Artery' 'RRAe' 'RRNn' 'RRAn' 'PosA' 'RRNe']
# ...

# %%
for feature in cont_feature:
    data=dataset.copy()
    if 0 in data[feature].unique():
        pass
    else:
        
        data[feature]=np.log(data[feature])
        data.boxplot(column=feature)
        plt.ylabel(feature)
        plt.title(feature)
        plt.show()

# %% [markdown]
# # relation between catogrical feature and dependent feature

# %%
for feature in cato_feature:
    data=dataset.copy()
    data.groupby(feature)["SalePrice"].mean().plot.bar()
    plt.show()
